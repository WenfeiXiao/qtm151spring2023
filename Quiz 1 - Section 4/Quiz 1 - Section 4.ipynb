# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your own code
print ("Fiona Xiao")
# Out:
# Fiona Xiao

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
## Write your own code

print ("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your own code


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Visualizing random variables </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a chi-square with (df = 5, size = 1000)
# - Generate "vec_z" from a chi-square distribution with (df = 1, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your own code

vec_x = np.random.chisquare(df = 5, size = 1000)
vec_z = np.random.chisquare(df=1, size = 1000)

fig, list_subfig = plt.subplots(1, 2,figsize = (7,3))
plt.tight_layout()

# First Figure
list_subfig[0].hist(x = vec_x)
list_subfig[0].set_title("Chi square random variable x with df =5")
list_subfig[0].set_xlabel("Value")
list_subfig[0].set_ylabel("Frequency")

# Second Figure
list_subfig[1].hist(x = vec_z)
list_subfig[1].set_title("Chi square random variable x with df =1")
list_subfig[1].set_xlabel("Value")
list_subfig[1].set_ylabel("Frequency")
# Out:
# Text(346.13131313131305, 0.5, 'Frequency')

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = sin(x) + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "sin()" function with vector arrays

# %%
# Write your own code
vec_y = np.sin(vec_x) +2*vec_x +5
plt.scatter(x= vec_x, y = vec_y, c='purple')
plt.ylabel("vec_y")
plt.xlabel("vec_x")
plt.title("plot of sinx + 2x +5")
plt.show()

# %% [markdown]
# ## <span style="color:darkblue"> Part II: Operations over multiple datasets </span>

# %% [markdown]
# <font size = "5">
#
# (c) Create two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on worldwide CO2 emissions

# %%
# Write your own code
list_names =["wdi_co2_2005.csv", "wdi_co2_2010.csv", "wdi_co2_2015.csv"]
list_years = [2005, 2010, 2015]

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2012, print the message
#
# $\qquad$ "This dataset contains information on or after 2012.
#
# - If the year $<$ 2012, print the message
#
# $\qquad$ "This dataset contains information before 2012"

# %%
# Write your own code
list_names =["wdi_co2_2005.csv", "wdi_co2_2010.csv", "wdi_co2_2015.csv"]

for datasetname in list_names:
    dataset_path = "data_quiz/" + datasetname
    dataset = pd.read_csv( dataset_path)
    print("Descriptive statistics (" + datasetname + ")")
    display(dataset.describe())

list_years = [2005, 2010, 2015]
index =0
for dataset in list_names:  
    if list_years[index] >= 2012:
        print ("This dataset"+str(dataset)+ " contains information on or after 2012")
    elif list_years[index]<2012:
            print ("This dataset"+str(dataset)+" contains information before 2012")
    index = index +1
# Out:
# Descriptive statistics (wdi_co2_2005.csv)
#          year  co2_gasfuel_kt  co2_liquidfuel_kt  Unnamed: 6  Unnamed: 7
# count   217.0    2.010000e+02       2.010000e+02         0.0         0.0
# mean   2005.0    2.687181e+04       4.810237e+04         NaN         NaN
# std       0.0    1.048300e+05       1.947701e+05         NaN         NaN
# min    2005.0    0.000000e+00       1.100100e+01         NaN         NaN
# 25%    2005.0    0.000000e+00       8.874140e+02         NaN         NaN
# 50%    2005.0    1.393460e+02       4.088705e+03         NaN         NaN
# 75%    2005.0    1.275749e+04       2.602470e+04         NaN         NaN
# max    2005.0    1.162996e+06       2.446413e+06         NaN         NaN
# Descriptive statistics (wdi_co2_2010.csv)
#          year  co2_gasfuel_kt  co2_liquidfuel_kt
# count   217.0    2.040000e+02       2.040000e+02
# mean   2010.0    3.057825e+04       4.850594e+04
# std       0.0    1.148652e+05       1.823041e+05
# min    2010.0    0.000000e+00       0.000000e+00
# 25%    2010.0    0.000000e+00       1.005675e+03
# 50%    2010.0    2.933600e+02       4.728596e+03
# 75%    2010.0    1.525289e+04       2.856501e+04
# max    2010.0    1.275075e+06       2.166284e+06
# Descriptive statistics (wdi_co2_2015.csv)
#          year  co2_gasfuel_kt  co2_liquidfuel_kt
# count   217.0    2.040000e+02       2.040000e+02
# mean   2015.0    3.221977e+04       4.933697e+04
# std       0.0    1.276608e+05       1.898681e+05
# min    2015.0    0.000000e+00       0.000000e+00
# 25%    2015.0    0.000000e+00       1.050595e+03
# 50%    2015.0    2.530230e+02       5.306149e+03
# 75%    2015.0    1.324337e+04       2.235220e+04
# max    2015.0    1.484156e+06       2.132548e+06
# This datasetwdi_co2_2005.csv contains information before 2012
# This datasetwdi_co2_2010.csv contains information before 2012
# This datasetwdi_co2_2015.csv contains information on or after 2012

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code

list_names =["data_quiz/wdi_co2_2005.csv", "data_quiz/wdi_co2_2010.csv", "data_quiz/wdi_co2_2015.csv"]
list_newnames = ["data_excel/wdi_co2_2005.xlsx", "data_excel/wdi_co2_2010.xlsx", "data_excel/wdi_co2_2015.xlsx"]

index =0 
for datasetname in list_names:
    dataset = pd.read_csv( datasetname)
    filename = list_newnames[index] 
    dataset.to_excel(filename)
    index = index +1

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ co2_gasfuel_kt = dataset["co2_gasfuel_kt"] <br>
#     $\qquad$ co2_liquidfuel_kt = dataset["co2_liquidfuel_kt"]
#
#     - Calculate the total CO2 emissions driven by gas and liquid fuel by adding the two previous variables.
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code
list_names =["data_quiz/wdi_co2_2005.csv", "data_quiz/wdi_co2_2010.csv", "data_quiz/wdi_co2_2015.csv"]
list_years = ["2005", "2010", "2015"]
index =0 
for datasetname in list_names:
    dataset = pd.read_csv( datasetname)
    co2_gasfuel_kt = dataset["co2_gasfuel_kt"]
    co2_liquidfuel_kt = dataset["co2_liquidfuel_kt"]
    co2_total_kt = co2_gasfuel_kt+co2_liquidfuel_kt
    plt.hist(x= co2_total_kt)
    plt.ylabel("Frequency")
    plt.xlabel("co2_total_kt")
    plt.title("Dataset " +  list_years[index]  + " total CO2 emissions driven by gas and liquid fuel")
    plt.show()
    index = index + 1
