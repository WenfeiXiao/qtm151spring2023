# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print ("Fiona Xiao")
# Out:
# Fiona Xiao

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:


print ("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
players = pd.read_csv("data_quiz/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "year"
# - If "year < 2016", status = "Joined before 2016"
# - If "height >= 2016", status = "Joined on 2016 or after"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Joined On" in the dataset <br>
# (be carefeful to write the "J" and "O" capitalized)
# - Create a new variable called "joined_after2016" <br>
# to assign each player to the correct age bracket
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_year(year):
    if(year < 2016):
        status = "Joined before 2016"
    else:
        status = "Joined on 2016 or after"
    return(status)

players["Joined_after2016"]    = players["Joined On"].apply(fn_year)

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Height(in cm)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Height(in cm)`    ``` inside .query()

# %%
# Write your own code
players.describe()
# Mean hright is 181.550839
height = 181.550839

player_heightabovemean = players.query("`Height(in cm)` >= @height")

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Value(in Euro)" column <br>
# from largest to smaller
# - Get a subset with the 5 players with the highest monetary valuation

# %%
# Write your own code

players_sorted = players.sort_values(by = "Value(in Euro)", ascending = False)
display(players_sorted.iloc[[0,1,2,3,4],:])
# Out:
#       Known As             Full Name  Overall  Potential  Value(in Euro)  \
# 4    K. Mbappé         Kylian Mbappé       91         95       190500000
# 21  E. Haaland        Erling Haaland       88         94       148000000
# 42  F. de Jong       Frenkie de Jong       87         92       116500000
# 82       Pedri  Pedro González López       85         93       116000000
# 5     M. Salah         Mohamed Salah       90         90       115500000
#
#    Positions Played Best Position  Nationality  \
# 4             ST,LW            ST       France
# 21               ST            ST       Norway
# 42               CM            CM  Netherlands
# 82               CM            CM        Spain
# 5                RW            RW        Egypt
#
#                                           Image Link  Age  ...  \
# 4   https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# 21  https://cdn.sofifa.net/players/239/085/23_60.png   21  ...
# 42  https://cdn.sofifa.net/players/228/702/23_60.png   25  ...
# 82  https://cdn.sofifa.net/players/251/854/23_60.png   19  ...
# 5   https://cdn.sofifa.net/players/209/331/23_60.png   30  ...
#
#     Weak Foot Rating  Skill Moves  International Reputation  \
# 4                  4            5                         4
# 21                 3            3                         4
# 42                 3            4                         3
# 82                 4            4                         2
# 5                  3            4                         4
#
#     National Team Name             National Team Image Link  \
# 4               France  https://cdn.sofifa.net/flags/fr.png
# 21              Norway  https://cdn.sofifa.net/flags/no.png
# 42         Netherlands  https://cdn.sofifa.net/flags/nl.png
# 82               Spain  https://cdn.sofifa.net/flags/es.png
# 5                    -                                    -
#
#     National Team Position  National Team Jersey Number Attacking Work Rate  \
# 4                       ST                           10                High
# 21                      ST                            9                High
# 42                     CDM                           21                High
# 82                      CM                           10                High
# 5                        -                            -                High
#
#    Defensive Work Rate         Joined_after2016
# 4                  Low  Joined on 2016 or after
# 21              Medium  Joined on 2016 or after
# 42              Medium  Joined on 2016 or after
# 82                High  Joined on 2016 or after
# 5               Medium  Joined on 2016 or after
#
# [5 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with four inputs $f(y,x,b0,b1)$
#
# <font size = "3">
#
# $\qquad e2 = (y - b_0 - b_1 * x)^2$
#
# - The function should return the sum of e2 entries
# - This is the residual sum of squares (rss)
# - Call the function "fn_rss"
# - Let $y$ be the column "Overall" (overall score)
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 50, b_1 = -6 )$ or <br>
# $\qquad (b_0 = 50, b_1 = 0.6 )$ or <br>
# $\qquad (b_0 = 50, b_1 = 6)$ <br>
# produce the lowest value of rss?

# %%
def fn_rss(y, x, b0, b1):
    e2 = (y-b0-b1 * x)**2
    return sum (e2)

fn_rss (players["Overall"], players["Age"], 50, -6)
# Value 537721853
fn_rss (players["Overall"], players["Age"], 50, 0.6)
# Value 696928.5
fn_rss (players["Overall"], players["Age"], 50, 6)
# Value 353393885

# The bo=50, b1=0.6 produce the lowest value of rss
# Out:
# 353393885

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [1,2]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "1" or "2" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"
# - Use .query() to subset all observations with status == 2.<br>
# store it in a new dataset called "data2"

# %%
list_status  = [1, 2]
list_prob  = [0.5,0.5]
n = len(players)

players["list_status"]= np.random.choice(list_status,
                                         size = n,
                                         p = list_prob)

display(players)
data1 = players.query('list_status == 1')
data2 = players.query('list_status == 2')
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Skill Moves  International Reputation  National Team Name  \
# 0                4                         5           Argentina
# 1                4                         4              France
# 2                4                         5              Poland
# 3                4                         4             Belgium
# 4                5                         4              France
# ...            ...                       ...                 ...
# 18534            2                         1                   -
# 18535            2                         1                   -
# 18536            2                         1                   -
# 18537            2                         1                   -
# 18538            2                         1                   -
#
#                   National Team Image Link National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                     RW
# 1      https://cdn.sofifa.net/flags/fr.png                     ST
# 2      https://cdn.sofifa.net/flags/pl.png                     ST
# 3      https://cdn.sofifa.net/flags/be.png                     RF
# 4      https://cdn.sofifa.net/flags/fr.png                     ST
# ...                                    ...                    ...
# 18534                                    -                      -
# 18535                                    -                      -
# 18536                                    -                      -
# 18537                                    -                      -
# 18538                                    -                      -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 0                               10                  Low                 Low
# 1                               19               Medium              Medium
# 2                                9                 High              Medium
# 3                                7                 High                High
# 4                               10                 High                 Low
# ...                            ...                  ...                 ...
# 18534                            -               Medium              Medium
# 18535                            -               Medium              Medium
# 18536                            -                 High              Medium
# 18537                            -               Medium              Medium
# 18538                            -               Medium              Medium
#
#               Joined_after2016 list_status
# 0      Joined on 2016 or after           2
# 1           Joined before 2016           2
# 2      Joined on 2016 or after           2
# 3           Joined before 2016           2
# 4      Joined on 2016 or after           2
# ...                        ...         ...
# 18534  Joined on 2016 or after           1
# 18535  Joined on 2016 or after           2
# 18536  Joined on 2016 or after           2
# 18537  Joined on 2016 or after           1
# 18538  Joined on 2016 or after           2
#
# [18539 rows x 34 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This function requires the two datasets you created in (e)
# - Display the distribution of "Potential" for "data1" and "data2"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code
list_dataset = [data1, data2]
for dataset in list_dataset:
    plt.hist(dataset["Potential"],alpha = 0.5)
plt.xlabel("Potential")
plt.ylabel("Frequency")
plt.legend(labels = ["Data 1", "Data 2"])
